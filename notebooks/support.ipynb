# %%
# !pip install python-dotenv
# !pip install openai

# %%
#notebook to test code

# %%
# Langchain
from langchain.sql_database import SQLDatabase
from langchain.callbacks import StreamlitCallbackHandler
from langchain_experimental.tools import PythonREPLTool
from langchain.agents import (AgentExecutor, ZeroShotAgent,load_tools)
from langchain.tools import Tool
from langchain_experimental.sql import SQLDatabaseChain
from langchain.chains import LLMChain
from langchain.chat_models import ChatOpenAI
from snowflake.snowpark import Session
from langchain_experimental.sql import SQLDatabaseChain
from sqlalchemy.dialects import registry

# %%
registry.load('snowflake')
# other imports

import logging
import os
import sys
from dotenv import load_dotenv, find_dotenv
# from prompts import get_system_prompt
# from snowflake.connector.errors import ProgrammingError 


# Streamlit
import streamlit as st


load_dotenv(find_dotenv(), override=True)

# Set up root logger to output to stdout
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
logger = logging.getLogger(__name__)
logger.info("This is an informational message.")

st.title("🏥 Catapult-Healthcare Bot")

#  openai_organization="YOUR_ORGANIZATION_ID"

OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
ACCOUNT = os.environ.get("ACCOUNT")
USER = os.environ.get("USER")
PASSWORD = os.environ.get("PASSWORD")
SCHEMA = os.environ.get("SCHEMA")
WAREHOUSE = os.environ.get("WAREHOUSE")
ROLE = os.environ.get("ROLE")
DATABASE = os.environ.get("DATABASE")


snowflake_url = f"snowflake://{USER}:{PASSWORD}@{ACCOUNT}/{DATABASE}/{SCHEMA}?warehouse={WAREHOUSE}&role={ROLE}"

db = SQLDatabase.from_uri(snowflake_url)

# we can see what information is passed to the LLM regarding the database
print(db.table_info)
    
llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY, 
                 model="gpt-4-1106-preview",
                 temperature=0)


connection_parameters = {
            "account": ACCOUNT,
            "user": USER,
            "password": PASSWORD,
            "role": ROLE,
            "warehouse": WAREHOUSE,
            "database": DATABASE,
            "schema": SCHEMA

        }

session = Session.builder.configs(connection_parameters).create()

DESCRIPTION = (
"You are given one table, the table name is in <tableName> tag, the columns are in <columns> tag.\n"
"The user will ask questions, for each question you should respond with an sql query based on the question and the table.\n"
"Do not use this tool to make charts\n"

"{context}"

"Here are 6 critical rules for the interaction you must abide:"
"<rules>"
"1. You MUST MUST wrap the generated sql code within ``` sql code markdown in this format e.g"
"```sql"
"(select 1) union (select 2)"
"```"
"2. If I don't tell you to find a limited set of results in the sql query or question, you MUST NOT limit the number of responses."
"3. Text / string where clauses must be fuzzy match e.g ilike %keyword%"
"4. Make sure to generate a single snowflake sql code, not multiple. "
"5. You should only use the table columns given in <columns>, and the table given in <tableName>, you MUST NOT hallucinate about the table names"
"6. DO NOT put numerical at the very front of sql variable."
"</rules>"
"Don't forget to use like %keyword% for fuzzy match queries (especially for variable_name column)"
"and wrap the generated sql code with ``` sql code markdown in this format e.g:"
"```sql"
"(select 1) union (select 2)"
"```"

"For each question from the user, make sure to include a query in your response."
)




QUALIFIED_TABLE_NAME = "CATAPULT_HEALTH_DB.POC_CATAPULT_HEALTH.HEALTHRECORDDATA"

TABLE_DESCRIPTION = """
This table is an electronic health record (EHR) system or a patient health database which has clinical or healthcare data from patients.
"""

PREFIX = "Complete this task in the best way possible. To be able to do it, you have to use the following tools:"


METADATA_QUERY = "SELECT VARIABLE_NAME, DEFINITION FROM CATAPULT_HEALTH_DB.POC_CATAPULT_HEALTH.HEALTHRECORDDATA_ATTRIBUTES;"

SUFFIX = """
"Begin! They are going to ask you for data and also ask you to create charts from that data.\n"
"Try to divide the input question into two parts: the part that refers to querying the database and the part of the input question where you are asked to graph the results of the question to the database."
"You will be acting as an AI Snowflake SQL Expert named Catapult Health Bot."
"Your goal is to give correct, executable sql query to users."
"You will be replying to users who will be confused if you don't respond in the character of Catapult Health Bot."
"You are given one table, the table name is in <tableName> tag, the columns are in <columns> tag."
"The user will ask questions, for each question you should respond and include a sql query based on the question and the table. "

"{context}"

" You MUST MUST wrap the generated python code within ``` python code markdown in this format e.g"
"```python"
"import pandas as pd"
"df = pd.DataFrame([(2878, datetime.date(2023, 2, 22)), (2909, datetime.date(2023, 2, 23)), (2977, datetime.date(2023, 2, 24)), (4184, datetime.date(2023, 2, 21)), (25123, datetime.date(2023, 2, 20)), (31730, datetime.date(2023, 2, 19)), (24394, datetime.date(2023, 2, 18))], columns=['cantidad_lineas_diferentes', 'fecha'])"
"st.bar_chart(df, x='fecha', y='cantidad_lineas_diferentes')
"```
"Use the 'Python_REPL' tool to make the charts, whenever the input begins in one of the following possible ways: " 
"show a bar chart..., show a pie chart..., show a line chart... plot a bar chart..., plot a pie chart..., plot a line chart... Most of the time, in the responses, you will have to show charts. "
"Don't explain the query before retrieving it,just show the SQL Query, the dataframe result and if it's the case, the chart required for the user. You MUST NOT be verbose on the explanation, just show the results."


"Use the 'Python_REPL' tool to make the charts, whenever the input begins in one of the following possible ways: "
"show a bar chart..., show a pie chart..., show a line chart... plot a bar chart..., plot a pie chart..., plot a line chart... Most of the time, in the responses, you will have to show charts. "
"To make these charts, you first need to create a pandas dataframe with the result of the database query. Intelligently select the columns of this dataframe that will be used to display the chart. For example:"
"import streamlit as st"
"import pandas as pd"
"import datetime"
"import plotly.express as px"
"df = pd.DataFrame([(2878, datetime.date(2023, 2, 22)), (2909, datetime.date(2023, 2, 23)), (2977, datetime.date(2023, 2, 24)), (4184, datetime.date(2023, 2, 21)), (25123, datetime.date(2023, 2, 20)), (31730, datetime.date(2023, 2, 19)), (24394, datetime.date(2023, 2, 18))], columns=['cantidad_lineas_diferentes', 'fecha'])"
"st.bar_chart(df, x='fecha', y='cantidad_lineas_diferentes')"
"These charts should be made using as input the results of the query to the table <tableName>. "
"To make these charts, use the Plotly library, importing only the necessary libraries. "
"Do not import libraries that will not be used. Import one library at a time. "
"There should be only one import per line. "
"Use the 'Python_REPL' tool for the final response, after obtaining the response to the database query. "
"The final response of the 'Python_REPL' tool should not be in triple quotes, the python code should be executed. "
"When you do not use the 'Python_REPL' tool, respond to the question in English. Use the 'Python_REPL' tool when the input begins in the following way: "
"Show a line chart..."

"Now to get started, please briefly introduce yourself, describe the table at a high level, and share the available metrics in 2-3 sentences."
"Then provide 3 example questions using bullet points."
"""


@st.cache_data(show_spinner=False)
def get_table_context(
    table_name: str, table_description: str, metadata_query: str = None
):
    table = table_name.split(".")
    conn = st.connection("snowflake")
    columns = conn.query(
        f"""
        SELECT COLUMN_NAME, DATA_TYPE FROM {table[0].upper()}.INFORMATION_SCHEMA.COLUMNS
        WHERE TABLE_SCHEMA = '{table[1].upper()}' AND TABLE_NAME = '{table[2].upper()}'
        """,
    )
    columns = "\n".join(
        [
            f"- **{columns['COLUMN_NAME'][i]}**: {columns['DATA_TYPE'][i]}"
            for i in range(len(columns["COLUMN_NAME"]))
        ]
    )
    context = f"""
Here is the table name <tableName> {'.'.join(table)} </tableName>

<tableDescription>{table_description}</tableDescription>

Here are the columns of the {'.'.join(table)}

<columns>\n\n{columns}\n\n</columns>
    """
    if metadata_query:
        metadata = conn.query(metadata_query)
        metadata = "\n".join(
            [
                f"- **{metadata['VARIABLE_NAME'][i]}**: {metadata['DEFINITION'][i]}"
                for i in range(len(metadata["VARIABLE_NAME"]))
            ]
        )
        context = context + f"\n\nAvailable variables by VARIABLE_NAME:\n\n{metadata}"
    return context


def get_system_prompt():
    table_context = get_table_context(
        table_name=QUALIFIED_TABLE_NAME,
        table_description=TABLE_DESCRIPTION,
        metadata_query=METADATA_QUERY,
    )
    return SUFFIX.format(context=table_context)


db_chain = SQLDatabaseChain.from_llm(
    llm=llm,
    db=db,
    verbose=True,  # Show its work
    return_direct=True,  # Return the results without sending back to the LLM
)


sql_query_tool = Tool(name="text_to_sql",
                      func=db_chain.run,
                      description=DESCRIPTION)
# Out:
# INFO:__main__:This is an informational message.
# INFO:snowflake.connector.connection:Snowflake Connector for Python Version: 3.5.0, Python Version: 3.10.0, Platform: macOS-13.4-arm64-arm-64bit
# DEBUG:snowflake.connector.connection:connect
# DEBUG:snowflake.connector.connection:__config
# INFO:snowflake.connector.connection:This connection is in OCSP Fail Open Mode. TLS Certificates would be checked for validity and revocation status. Any other Certificate Revocation related exceptions or OCSP Responder failures would be disregarded in favor of connectivity.
# DEBUG:snowflake.connector.converter:use_numpy: False
# DEBUG:snowflake.connector.connection:REST API object was created: sn37336.sa-east-1.aws.snowflakecomputing.com:443
# DEBUG:snowflake.connector.auth._auth:authenticate
# DEBUG:snowflake.connector.auth._auth:assertion content: *********
# DEBUG:snowflake.connector.auth._auth:account=sn37336, user=QUBIKA_ELHAIEK, database=CATAPULT_HEALTH_DB, schema=POC_CATAPULT_HEALTH, warehouse=ML_ENGINEER_WH, role=_ML_ENGINEER_CATAPULT_HEALTH_DB, request_id=751614eb-5e0f-4282-b11d-fd6c779a18eb
# DEBUG:snowflake.connector.auth._auth:body['data']: {'CLIENT_APP_ID': 'SnowflakeSQLAlchemy', 'CLIENT_APP_VERSION': '1.5.1', 'SVN_REVISION': None, 'ACCOUNT_NAME': 'sn37336', 'LOGIN_NAME': 'QUBIKA_ELHAIEK', 'CLIENT_ENVIRONMENT': {'APPLICATION': 'SnowflakeSQLAlchemy', 'OS': 'Darwin', 'OS_VERSION': 'macOS-13.4-arm64-arm-64bit', 'PYTHON_VERSION': '3.10.0', 'PYTHON_RUNTIME': 'CPython', 'PYTHON_COMPILER': 'Clang 12.0.0 ', 'OCSP_MODE': 'FAIL_OPEN', 'TRACING': 10, 'LOGIN_TIMEOUT': None, 'NETWORK_TIMEOUT': None, 'SOCKET_TIMEOUT': None}, 'SESSION_PARAMETERS': {'AUTOCOMMIT': False, 'CLIENT_PREFETCH_THREADS': 4}}
# DEBUG:snowflake.connector.vendored.urllib3.util.retry:Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# DEBUG:snowflake.connector.vendored.urllib3.util.retry:Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: d88508f7-b36b-483a-a47d-27b4cbc78f07
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:Starting new HTTPS connection (1): sn37336.sa-east-1.aws.snowflakecomputing.com:443
# DEBUG:snowflake.connector.ssl_wrap_socket:OCSP Mode: FAIL_OPEN, OCSP response cache file name: None
# DEBUG:snowflake.connector.ocsp_snowflake:ocsp_response_cache_uri: file:///Users/miguelelhaiek/Library/Caches/Snowflake/ocsp_response_cache.json
# DEBUG:snowflake.connector.ocsp_snowflake:OCSP_VALIDATION_CACHE size: 200
# DEBUG:snowflake.connector.ocsp_snowflake:OCSP response cache server is enabled: http://ocsp.snowflakecomputing.com/ocsp_response_cache.json
# DEBUG:snowflake.connector.ocsp_snowflake:OCSP dynamic cache server RETRY URL: None
# DEBUG:snowflake.connector.ocsp_snowflake:validating certificate: sn37336.sa-east-1.aws.snowflakecomputing.com
# DEBUG:snowflake.connector.ocsp_asn1crypto:# of certificates: 4
# DEBUG:snowflake.connector.ocsp_asn1crypto:subject: OrderedDict([('common_name', '*.sa-east-1.snowflakecomputing.com')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')]), issuer: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:not found issuer_der: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# DEBUG:snowflake.connector.ocsp_snowflake:hit cache for subject: OrderedDict([('common_name', '*.sa-east-1.snowflakecomputing.com')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:Verifying the attached certificate is signed by the issuer. Valid Not After: 2025-08-23 22:57:03+00:00
# DEBUG:snowflake.connector.ocsp_snowflake:hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:Verifying the attached certificate is signed by the issuer. Valid Not After: 2025-08-23 22:59:53+00:00
# DEBUG:snowflake.connector.ocsp_snowflake:hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-06-06 12:00:00+00:00
# DEBUG:snowflake.connector.ocsp_snowflake:hit cache for subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# DEBUG:snowflake.connector.ocsp_snowflake:ok
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /session/v1/login-request?request_id=751614eb-5e0f-4282-b11d-fd6c779a18eb&databaseName=CATAPULT_HEALTH_DB&schemaName=POC_CATAPULT_HEALTH&warehouse=ML_ENGINEER_WH&roleName=_ML_ENGINEER_CATAPULT_HEALTH_DB&request_guid=d88508f7-b36b-483a-a47d-27b4cbc78f07 HTTP/1.1" 200 1618
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.auth._auth:completed authentication
# DEBUG:snowflake.connector.auth._auth:token = ******
# DEBUG:snowflake.connector.auth._auth:master_token = ******
# DEBUG:snowflake.connector.auth._auth:id_token = NULL
# DEBUG:snowflake.connector.auth._auth:mfa_token = NULL
# DEBUG:snowflake.connector.connection:cursor
# DEBUG:snowflake.connector.cursor:executing SQL/command
# DEBUG:snowflake.connector.connection:parameters: {}
# DEBUG:snowflake.connector.cursor:binding: [select current_database(), current_schema();] with input=[{}], processed=[{}]
# INFO:snowflake.connector.cursor:query: [select current_database(), current_schema();]
# DEBUG:snowflake.connector.connection:sequence counter: 1
# DEBUG:snowflake.connector.cursor:Request id: ec6692f9-a7a8-4c32-84c1-b9ce0bbe704b
# DEBUG:snowflake.connector.cursor:running query [select current_database(), current_schema();]
# DEBUG:snowflake.connector.cursor:is_file_transfer: True
# DEBUG:snowflake.connector.connection:_cmd_query
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict() called
# DEBUG:snowflake.connector.connection:sql=[select current_database(), current_schema();], sequence_id=[1], is_file_transfer=[False]
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: 7ffe5d6c-89b2-4c52-b4c5-f28c106fa71b
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /queries/v1/query-request?requestId=ec6692f9-a7a8-4c32-84c1-b9ce0bbe704b&request_guid=7ffe5d6c-89b2-4c52-b4c5-f28c106fa71b HTTP/1.1" 200 1819
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.network:Query id: 01b05f7b-0000-2da6-0000-38950011a5c6
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() called: data from server: {'entries': [{'id': 0, 'timestamp': 43022126577552, 'priority': 0}]}
# DEBUG:snowflake.connector._query_context_cache:deserialize {'id': 0, 'timestamp': 43022126577552, 'priority': 0}
# DEBUG:snowflake.connector._query_context_cache:sync_priority_map called priority_map size = 0, new_priority_map size = 1
# DEBUG:snowflake.connector._query_context_cache:trim_cache() called. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:trim_cache() returns. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() returns
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022126577552, 0)
# DEBUG:snowflake.connector.cursor:sfqid: 01b05f7b-0000-2da6-0000-38950011a5c6
# INFO:snowflake.connector.cursor:query execution done
# DEBUG:snowflake.connector.cursor:SUCCESS
# DEBUG:snowflake.connector.cursor:PUT OR GET: False
# DEBUG:snowflake.connector.cursor:Query result format: arrow
# INFO:snowflake.connector.cursor:Number of results in first chunk: 1
# DEBUG:snowflake.connector.result_batch:Using nanoarrow as the arrow data converter
# DEBUG:snowflake.connector.CArrowIterator:Arrow BatchSize: 1
# DEBUG:snowflake.connector.CArrowIterator:Arrow chunk info: batchCount 1, columnCount 2, use_numpy: 0
# DEBUG:snowflake.connector.nanoarrow_arrow_iterator:Batches read: 0
# DEBUG:snowflake.connector.result_set:beginning to schedule result batch downloads
# DEBUG:snowflake.connector.CArrowIterator:Current batch index: 0, rows in current batch: 1
# DEBUG:snowflake.connector.connection:cursor
# DEBUG:snowflake.connector.cursor:executing SQL/command
# DEBUG:snowflake.connector.cursor:binding: [ROLLBACK] with input=[None], processed=[{}]
# INFO:snowflake.connector.cursor:query: [ROLLBACK]
# DEBUG:snowflake.connector.connection:sequence counter: 2
# DEBUG:snowflake.connector.cursor:Request id: 307ce691-7e6c-46f4-98c5-bbcb60c43181
# DEBUG:snowflake.connector.cursor:running query [ROLLBACK]
# DEBUG:snowflake.connector.cursor:is_file_transfer: True
# DEBUG:snowflake.connector.connection:_cmd_query
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict() called
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022126577552, 0)
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict(): data to send to server {'entries': [{'id': 0, 'timestamp': 43022126577552, 'priority': 0, 'context': {}}]}
# DEBUG:snowflake.connector.connection:sql=[ROLLBACK], sequence_id=[2], is_file_transfer=[False]
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: e1e7b855-5d68-4817-b192-9708c60c0a5d
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /queries/v1/query-request?requestId=307ce691-7e6c-46f4-98c5-bbcb60c43181&request_guid=e1e7b855-5d68-4817-b192-9708c60c0a5d HTTP/1.1" 200 1265
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.network:Query id: 01b05f7b-0000-2da6-0000-38950011a5ca
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() called: data from server: {'entries': [{'id': 0, 'timestamp': 43022126760597, 'priority': 0}]}
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022126577552, 0)
# DEBUG:snowflake.connector._query_context_cache:deserialize {'id': 0, 'timestamp': 43022126760597, 'priority': 0}
# DEBUG:snowflake.connector._query_context_cache:sync_priority_map called priority_map size = 0, new_priority_map size = 1
# DEBUG:snowflake.connector._query_context_cache:trim_cache() called. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:trim_cache() returns. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() returns
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022126760597, 0)
# DEBUG:snowflake.connector.cursor:sfqid: 01b05f7b-0000-2da6-0000-38950011a5ca
# INFO:snowflake.connector.cursor:query execution done
# DEBUG:snowflake.connector.cursor:SUCCESS
# DEBUG:snowflake.connector.cursor:PUT OR GET: False
# DEBUG:snowflake.connector.cursor:Query result format: json
# DEBUG:snowflake.connector.result_batch:parsing for result batch id: 1
# INFO:snowflake.connector.cursor:Number of results in first chunk: 1
# DEBUG:snowflake.connector.connection:cursor
# DEBUG:snowflake.connector.cursor:executing SQL/command
# DEBUG:snowflake.connector.cursor:binding: [ROLLBACK] with input=[None], processed=[{}]
# INFO:snowflake.connector.cursor:query: [ROLLBACK]
# DEBUG:snowflake.connector.connection:sequence counter: 3
# DEBUG:snowflake.connector.cursor:Request id: f1be23b0-a337-420b-9b30-c9cbaedd148c
# DEBUG:snowflake.connector.cursor:running query [ROLLBACK]
# DEBUG:snowflake.connector.cursor:is_file_transfer: True
# DEBUG:snowflake.connector.connection:_cmd_query
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict() called
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022126760597, 0)
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict(): data to send to server {'entries': [{'id': 0, 'timestamp': 43022126760597, 'priority': 0, 'context': {}}]}
# DEBUG:snowflake.connector.connection:sql=[ROLLBACK], sequence_id=[3], is_file_transfer=[False]
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: 23f3e895-0d3c-4de3-8fa1-23d9b6bf8204
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /queries/v1/query-request?requestId=f1be23b0-a337-420b-9b30-c9cbaedd148c&request_guid=23f3e895-0d3c-4de3-8fa1-23d9b6bf8204 HTTP/1.1" 200 1263
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.network:Query id: 01b05f7b-0000-2da8-0000-38950011b5b6
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() called: data from server: {'entries': [{'id': 0, 'timestamp': 43022126943142, 'priority': 0}]}
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022126760597, 0)
# DEBUG:snowflake.connector._query_context_cache:deserialize {'id': 0, 'timestamp': 43022126943142, 'priority': 0}
# DEBUG:snowflake.connector._query_context_cache:sync_priority_map called priority_map size = 0, new_priority_map size = 1
# DEBUG:snowflake.connector._query_context_cache:trim_cache() called. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:trim_cache() returns. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() returns
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022126943142, 0)
# DEBUG:snowflake.connector.cursor:sfqid: 01b05f7b-0000-2da8-0000-38950011b5b6
# INFO:snowflake.connector.cursor:query execution done
# DEBUG:snowflake.connector.cursor:SUCCESS
# DEBUG:snowflake.connector.cursor:PUT OR GET: False
# DEBUG:snowflake.connector.cursor:Query result format: json
# DEBUG:snowflake.connector.result_batch:parsing for result batch id: 1
# INFO:snowflake.connector.cursor:Number of results in first chunk: 1
# DEBUG:snowflake.connector.connection:cursor
# DEBUG:snowflake.connector.cursor:executing SQL/command
# DEBUG:snowflake.connector.connection:parameters: {}
# DEBUG:snowflake.connector.cursor:binding: [SHOW /* sqlalchemy:get_table_names */ TABLES IN poc_catapult_health] with input=[{}], processed=[{}]
# INFO:snowflake.connector.cursor:query: [SHOW /* sqlalchemy:get_table_names */ TABLES IN poc_catapult_health]
# DEBUG:snowflake.connector.connection:sequence counter: 4
# DEBUG:snowflake.connector.cursor:Request id: 5de2bcec-4214-4a84-9a45-8dc1c16a9f40
# DEBUG:snowflake.connector.cursor:running query [SHOW /* sqlalchemy:get_table_names */ TABLES IN poc_catapult_health]
# DEBUG:snowflake.connector.cursor:is_file_transfer: True
# DEBUG:snowflake.connector.connection:_cmd_query
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict() called
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022126943142, 0)
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict(): data to send to server {'entries': [{'id': 0, 'timestamp': 43022126943142, 'priority': 0, 'context': {}}]}
# DEBUG:snowflake.connector.connection:sql=[SHOW /* sqlalchemy:get_table_names */ TABLES IN poc_catapult_health], sequence_id=[4], is_file_transfer=[False]
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: cf3acc80-e48f-4b86-ba6d-d6b581517c89
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /queries/v1/query-request?requestId=5de2bcec-4214-4a84-9a45-8dc1c16a9f40&request_guid=cf3acc80-e48f-4b86-ba6d-d6b581517c89 HTTP/1.1" 200 1598
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.network:Query id: 01b05f7b-0000-2da8-0000-38950011b5ba
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() called: data from server: {'entries': [{'id': 0, 'timestamp': 43022127184071, 'priority': 0}]}
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022126943142, 0)
# DEBUG:snowflake.connector._query_context_cache:deserialize {'id': 0, 'timestamp': 43022127184071, 'priority': 0}
# DEBUG:snowflake.connector._query_context_cache:sync_priority_map called priority_map size = 0, new_priority_map size = 1
# DEBUG:snowflake.connector._query_context_cache:trim_cache() called. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:trim_cache() returns. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() returns
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127184071, 0)
# DEBUG:snowflake.connector.cursor:sfqid: 01b05f7b-0000-2da8-0000-38950011b5ba
# INFO:snowflake.connector.cursor:query execution done
# DEBUG:snowflake.connector.cursor:SUCCESS
# DEBUG:snowflake.connector.cursor:PUT OR GET: False
# DEBUG:snowflake.connector.cursor:Query result format: json
# DEBUG:snowflake.connector.result_batch:parsing for result batch id: 2
# INFO:snowflake.connector.cursor:Number of results in first chunk: 2
# DEBUG:snowflake.connector.result_set:beginning to schedule result batch downloads
# DEBUG:snowflake.connector.connection:cursor
# DEBUG:snowflake.connector.cursor:executing SQL/command
# DEBUG:snowflake.connector.cursor:binding: [ROLLBACK] with input=[None], processed=[{}]
# INFO:snowflake.connector.cursor:query: [ROLLBACK]
# DEBUG:snowflake.connector.connection:sequence counter: 5
# DEBUG:snowflake.connector.cursor:Request id: bc008de4-8d26-47c3-86ed-9e39d6a6470f
# DEBUG:snowflake.connector.cursor:running query [ROLLBACK]
# DEBUG:snowflake.connector.cursor:is_file_transfer: True
# DEBUG:snowflake.connector.connection:_cmd_query
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict() called
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127184071, 0)
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict(): data to send to server {'entries': [{'id': 0, 'timestamp': 43022127184071, 'priority': 0, 'context': {}}]}
# DEBUG:snowflake.connector.connection:sql=[ROLLBACK], sequence_id=[5], is_file_transfer=[False]
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: 40b05391-cc0c-4904-bb36-81784f501d73
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /queries/v1/query-request?requestId=bc008de4-8d26-47c3-86ed-9e39d6a6470f&request_guid=40b05391-cc0c-4904-bb36-81784f501d73 HTTP/1.1" 200 1265
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.network:Query id: 01b05f7b-0000-2da8-0000-38950011b5be
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() called: data from server: {'entries': [{'id': 0, 'timestamp': 43022127362686, 'priority': 0}]}
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127184071, 0)
# DEBUG:snowflake.connector._query_context_cache:deserialize {'id': 0, 'timestamp': 43022127362686, 'priority': 0}
# DEBUG:snowflake.connector._query_context_cache:sync_priority_map called priority_map size = 0, new_priority_map size = 1
# DEBUG:snowflake.connector._query_context_cache:trim_cache() called. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:trim_cache() returns. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() returns
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127362686, 0)
# DEBUG:snowflake.connector.cursor:sfqid: 01b05f7b-0000-2da8-0000-38950011b5be
# INFO:snowflake.connector.cursor:query execution done
# DEBUG:snowflake.connector.cursor:SUCCESS
# DEBUG:snowflake.connector.cursor:PUT OR GET: False
# DEBUG:snowflake.connector.cursor:Query result format: json
# DEBUG:snowflake.connector.result_batch:parsing for result batch id: 1
# INFO:snowflake.connector.cursor:Number of results in first chunk: 1
# DEBUG:snowflake.connector.connection:cursor
# DEBUG:snowflake.connector.cursor:executing SQL/command
# DEBUG:snowflake.connector.cursor:binding: [ROLLBACK] with input=[None], processed=[{}]
# INFO:snowflake.connector.cursor:query: [ROLLBACK]
# DEBUG:snowflake.connector.connection:sequence counter: 6
# DEBUG:snowflake.connector.cursor:Request id: 25ab8cd5-7b6d-4ec5-b071-857fb36e9afb
# DEBUG:snowflake.connector.cursor:running query [ROLLBACK]
# DEBUG:snowflake.connector.cursor:is_file_transfer: True
# DEBUG:snowflake.connector.connection:_cmd_query
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict() called
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127362686, 0)
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict(): data to send to server {'entries': [{'id': 0, 'timestamp': 43022127362686, 'priority': 0, 'context': {}}]}
# DEBUG:snowflake.connector.connection:sql=[ROLLBACK], sequence_id=[6], is_file_transfer=[False]
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: aac9a3d5-4537-4f18-b303-53fbafe09945
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /queries/v1/query-request?requestId=25ab8cd5-7b6d-4ec5-b071-857fb36e9afb&request_guid=aac9a3d5-4537-4f18-b303-53fbafe09945 HTTP/1.1" 200 1263
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.network:Query id: 01b05f7b-0000-2da6-0000-38950011a5ce
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() called: data from server: {'entries': [{'id': 0, 'timestamp': 43022127561276, 'priority': 0}]}
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127362686, 0)
# DEBUG:snowflake.connector._query_context_cache:deserialize {'id': 0, 'timestamp': 43022127561276, 'priority': 0}
# DEBUG:snowflake.connector._query_context_cache:sync_priority_map called priority_map size = 0, new_priority_map size = 1
# DEBUG:snowflake.connector._query_context_cache:trim_cache() called. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:trim_cache() returns. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() returns
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127561276, 0)
# DEBUG:snowflake.connector.cursor:sfqid: 01b05f7b-0000-2da6-0000-38950011a5ce
# INFO:snowflake.connector.cursor:query execution done
# DEBUG:snowflake.connector.cursor:SUCCESS
# DEBUG:snowflake.connector.cursor:PUT OR GET: False
# DEBUG:snowflake.connector.cursor:Query result format: json
# DEBUG:snowflake.connector.result_batch:parsing for result batch id: 1
# INFO:snowflake.connector.cursor:Number of results in first chunk: 1
# DEBUG:snowflake.connector.connection:cursor
# DEBUG:snowflake.connector.cursor:executing SQL/command
# DEBUG:snowflake.connector.connection:parameters: {}
# DEBUG:snowflake.connector.cursor:binding: [SHOW /* sqlalchemy:get_table_names */ TABLES IN poc_catapult_health] with input=[{}], processed=[{}]
# INFO:snowflake.connector.cursor:query: [SHOW /* sqlalchemy:get_table_names */ TABLES IN poc_catapult_health]
# DEBUG:snowflake.connector.connection:sequence counter: 7
# DEBUG:snowflake.connector.cursor:Request id: 95e075f2-5a6f-48cd-ac4d-c3aa1d60a21d
# DEBUG:snowflake.connector.cursor:running query [SHOW /* sqlalchemy:get_table_names */ TABLES IN poc_catapult_health]
# DEBUG:snowflake.connector.cursor:is_file_transfer: True
# DEBUG:snowflake.connector.connection:_cmd_query
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict() called
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127561276, 0)
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict(): data to send to server {'entries': [{'id': 0, 'timestamp': 43022127561276, 'priority': 0, 'context': {}}]}
# DEBUG:snowflake.connector.connection:sql=[SHOW /* sqlalchemy:get_table_names */ TABLES IN poc_catapult_health], sequence_id=[7], is_file_transfer=[False]
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: b66579b5-f967-495e-acbe-b83e2ce4decf
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /queries/v1/query-request?requestId=95e075f2-5a6f-48cd-ac4d-c3aa1d60a21d&request_guid=b66579b5-f967-495e-acbe-b83e2ce4decf HTTP/1.1" 200 1604
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.network:Query id: 01b05f7b-0000-2da6-0000-38950011a5d2
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() called: data from server: {'entries': [{'id': 0, 'timestamp': 43022127820522, 'priority': 0}]}
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127561276, 0)
# DEBUG:snowflake.connector._query_context_cache:deserialize {'id': 0, 'timestamp': 43022127820522, 'priority': 0}
# DEBUG:snowflake.connector._query_context_cache:sync_priority_map called priority_map size = 0, new_priority_map size = 1
# DEBUG:snowflake.connector._query_context_cache:trim_cache() called. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:trim_cache() returns. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() returns
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127820522, 0)
# DEBUG:snowflake.connector.cursor:sfqid: 01b05f7b-0000-2da6-0000-38950011a5d2
# INFO:snowflake.connector.cursor:query execution done
# DEBUG:snowflake.connector.cursor:SUCCESS
# DEBUG:snowflake.connector.cursor:PUT OR GET: False
# DEBUG:snowflake.connector.cursor:Query result format: json
# DEBUG:snowflake.connector.result_batch:parsing for result batch id: 2
# INFO:snowflake.connector.cursor:Number of results in first chunk: 2
# DEBUG:snowflake.connector.result_set:beginning to schedule result batch downloads
# DEBUG:snowflake.connector.connection:cursor
# DEBUG:snowflake.connector.cursor:executing SQL/command
# DEBUG:snowflake.connector.connection:parameters: {}
# DEBUG:snowflake.connector.cursor:binding: [select current_database(), current_schema();] with input=[{}], processed=[{}]
# INFO:snowflake.connector.cursor:query: [select current_database(), current_schema();]
# DEBUG:snowflake.connector.connection:sequence counter: 8
# DEBUG:snowflake.connector.cursor:Request id: 6745c346-eb99-4001-bc2a-914446bf3eee
# DEBUG:snowflake.connector.cursor:running query [select current_database(), current_schema();]
# DEBUG:snowflake.connector.cursor:is_file_transfer: True
# DEBUG:snowflake.connector.connection:_cmd_query
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict() called
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127820522, 0)
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict(): data to send to server {'entries': [{'id': 0, 'timestamp': 43022127820522, 'priority': 0, 'context': {}}]}
# DEBUG:snowflake.connector.connection:sql=[select current_database(), current_schema();], sequence_id=[8], is_file_transfer=[False]
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: c7c2466d-5e4c-47aa-88b2-2b6285790efc
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /queries/v1/query-request?requestId=6745c346-eb99-4001-bc2a-914446bf3eee&request_guid=c7c2466d-5e4c-47aa-88b2-2b6285790efc HTTP/1.1" 200 1821
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.network:Query id: 01b05f7b-0000-2da8-0000-38950011b5c2
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() called: data from server: {'entries': [{'id': 0, 'timestamp': 43022127989651, 'priority': 0}]}
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127820522, 0)
# DEBUG:snowflake.connector._query_context_cache:deserialize {'id': 0, 'timestamp': 43022127989651, 'priority': 0}
# DEBUG:snowflake.connector._query_context_cache:sync_priority_map called priority_map size = 0, new_priority_map size = 1
# DEBUG:snowflake.connector._query_context_cache:trim_cache() called. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:trim_cache() returns. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() returns
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127989651, 0)
# DEBUG:snowflake.connector.cursor:sfqid: 01b05f7b-0000-2da8-0000-38950011b5c2
# INFO:snowflake.connector.cursor:query execution done
# DEBUG:snowflake.connector.cursor:SUCCESS
# DEBUG:snowflake.connector.cursor:PUT OR GET: False
# DEBUG:snowflake.connector.cursor:Query result format: arrow
# INFO:snowflake.connector.cursor:Number of results in first chunk: 1
# DEBUG:snowflake.connector.result_batch:Using nanoarrow as the arrow data converter
# DEBUG:snowflake.connector.CArrowIterator:Arrow BatchSize: 1
# DEBUG:snowflake.connector.CArrowIterator:Arrow chunk info: batchCount 1, columnCount 2, use_numpy: 0
# DEBUG:snowflake.connector.nanoarrow_arrow_iterator:Batches read: 0
# DEBUG:snowflake.connector.result_set:beginning to schedule result batch downloads
# DEBUG:snowflake.connector.CArrowIterator:Current batch index: 0, rows in current batch: 1
# DEBUG:snowflake.connector.connection:cursor
# DEBUG:snowflake.connector.cursor:executing SQL/command
# DEBUG:snowflake.connector.connection:parameters: {}
# DEBUG:snowflake.connector.cursor:binding: [SHOW /* sqlalchemy:_get_schema_primary_keys */PRIMARY KEYS IN SCHEMA catapult_he...] with input=[{}], processed=[{}]
# INFO:snowflake.connector.cursor:query: [SHOW /* sqlalchemy:_get_schema_primary_keys */PRIMARY KEYS IN SCHEMA catapult_he...]
# DEBUG:snowflake.connector.connection:sequence counter: 9
# DEBUG:snowflake.connector.cursor:Request id: 040df51a-8857-43a5-9cc7-8ec4b6f14033
# DEBUG:snowflake.connector.cursor:running query [SHOW /* sqlalchemy:_get_schema_primary_keys */PRIMARY KEYS IN SCHEMA catapult_he...]
# DEBUG:snowflake.connector.cursor:is_file_transfer: True
# DEBUG:snowflake.connector.connection:_cmd_query
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict() called
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127989651, 0)
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict(): data to send to server {'entries': [{'id': 0, 'timestamp': 43022127989651, 'priority': 0, 'context': {}}]}
# DEBUG:snowflake.connector.connection:sql=[SHOW /* sqlalchemy:_get_schema_primary_keys */PRIMARY KEYS IN SCHEMA catapult_he...], sequence_id=[9], is_file_transfer=[False]
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: a32d1e7a-1a3e-4426-a922-a211cf4b0660
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /queries/v1/query-request?requestId=040df51a-8857-43a5-9cc7-8ec4b6f14033&request_guid=a32d1e7a-1a3e-4426-a922-a211cf4b0660 HTTP/1.1" 200 1377
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.network:Query id: 01b05f7b-0000-2da8-0000-38950011b5c6
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() called: data from server: {'entries': [{'id': 0, 'timestamp': 43022128201726, 'priority': 0}]}
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022127989651, 0)
# DEBUG:snowflake.connector._query_context_cache:deserialize {'id': 0, 'timestamp': 43022128201726, 'priority': 0}
# DEBUG:snowflake.connector._query_context_cache:sync_priority_map called priority_map size = 0, new_priority_map size = 1
# DEBUG:snowflake.connector._query_context_cache:trim_cache() called. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:trim_cache() returns. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() returns
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022128201726, 0)
# DEBUG:snowflake.connector.cursor:sfqid: 01b05f7b-0000-2da8-0000-38950011b5c6
# INFO:snowflake.connector.cursor:query execution done
# DEBUG:snowflake.connector.cursor:SUCCESS
# DEBUG:snowflake.connector.cursor:PUT OR GET: False
# DEBUG:snowflake.connector.cursor:Query result format: json
# DEBUG:snowflake.connector.result_batch:parsing for result batch id: 0
# INFO:snowflake.connector.cursor:Number of results in first chunk: 0
# DEBUG:snowflake.connector.result_set:beginning to schedule result batch downloads
# DEBUG:snowflake.connector.connection:cursor
# DEBUG:snowflake.connector.cursor:executing SQL/command
# DEBUG:snowflake.connector.connection:parameters: {'table_schema': "'POC_CATAPULT_HEALTH'"}
# DEBUG:snowflake.connector.cursor:binding: [SELECT /* sqlalchemy:_get_schema_columns */ ic.table_name, ic.column_name, ic.da...] with input=[{'table_schema': 'POC_CATAPULT_HEALTH'}], processed=[{'table_schema': "'POC_CATAPULT_HEALTH'"}]
# INFO:snowflake.connector.cursor:query: [SELECT /* sqlalchemy:_get_schema_columns */ ic.table_name, ic.column_name, ic.da...]
# DEBUG:snowflake.connector.connection:sequence counter: 10
# DEBUG:snowflake.connector.cursor:Request id: 9422c8b7-6817-4637-a33d-192c17d6d507
# DEBUG:snowflake.connector.cursor:running query [SELECT /* sqlalchemy:_get_schema_columns */ ic.table_name, ic.column_name, ic.da...]
# DEBUG:snowflake.connector.cursor:is_file_transfer: True
# DEBUG:snowflake.connector.connection:_cmd_query
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict() called
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022128201726, 0)
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict(): data to send to server {'entries': [{'id': 0, 'timestamp': 43022128201726, 'priority': 0, 'context': {}}]}
# DEBUG:snowflake.connector.connection:sql=[SELECT /* sqlalchemy:_get_schema_columns */ ic.table_name, ic.column_name, ic.da...], sequence_id=[10], is_file_transfer=[False]
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: 113a152a-b280-4505-9117-3b01de47ccf1
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /queries/v1/query-request?requestId=9422c8b7-6817-4637-a33d-192c17d6d507&request_guid=113a152a-b280-4505-9117-3b01de47ccf1 HTTP/1.1" 200 8083
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.network:Query id: 01b05f7b-0000-2da6-0000-38950011a5d6
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() called: data from server: {'entries': [{'id': 0, 'timestamp': 43022130282202, 'priority': 0}]}
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022128201726, 0)
# DEBUG:snowflake.connector._query_context_cache:deserialize {'id': 0, 'timestamp': 43022130282202, 'priority': 0}
# DEBUG:snowflake.connector._query_context_cache:sync_priority_map called priority_map size = 0, new_priority_map size = 1
# DEBUG:snowflake.connector._query_context_cache:trim_cache() called. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:trim_cache() returns. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() returns
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022130282202, 0)
# DEBUG:snowflake.connector.cursor:sfqid: 01b05f7b-0000-2da6-0000-38950011a5d6
# INFO:snowflake.connector.cursor:query execution done
# DEBUG:snowflake.connector.cursor:SUCCESS
# DEBUG:snowflake.connector.cursor:PUT OR GET: False
# DEBUG:snowflake.connector.cursor:Query result format: arrow
# INFO:snowflake.connector.cursor:Number of results in first chunk: 113
# DEBUG:snowflake.connector.result_batch:Using nanoarrow as the arrow data converter
# DEBUG:snowflake.connector.CArrowIterator:Arrow BatchSize: 8
# DEBUG:snowflake.connector.CArrowIterator:Arrow chunk info: batchCount 8, columnCount 12, use_numpy: 0
# DEBUG:snowflake.connector.nanoarrow_arrow_iterator:Batches read: 0
# DEBUG:snowflake.connector.result_set:beginning to schedule result batch downloads
# DEBUG:snowflake.connector.CArrowIterator:Current batch index: 0, rows in current batch: 14
# DEBUG:snowflake.connector.CArrowIterator:Current batch index: 1, rows in current batch: 14
# DEBUG:snowflake.connector.CArrowIterator:Current batch index: 2, rows in current batch: 14
# DEBUG:snowflake.connector.CArrowIterator:Current batch index: 3, rows in current batch: 14
# DEBUG:snowflake.connector.CArrowIterator:Current batch index: 4, rows in current batch: 14
# DEBUG:snowflake.connector.CArrowIterator:Current batch index: 5, rows in current batch: 14
# DEBUG:snowflake.connector.CArrowIterator:Current batch index: 6, rows in current batch: 14
# DEBUG:snowflake.connector.CArrowIterator:Current batch index: 7, rows in current batch: 15
# DEBUG:snowflake.connector.connection:cursor
# DEBUG:snowflake.connector.cursor:executing SQL/command
# DEBUG:snowflake.connector.connection:parameters: {}
# DEBUG:snowflake.connector.cursor:binding: [SHOW /* sqlalchemy:_get_schema_foreign_keys */ IMPORTED KEYS IN SCHEMA catapult_...] with input=[{}], processed=[{}]
# INFO:snowflake.connector.cursor:query: [SHOW /* sqlalchemy:_get_schema_foreign_keys */ IMPORTED KEYS IN SCHEMA catapult_...]
# DEBUG:snowflake.connector.connection:sequence counter: 11
# DEBUG:snowflake.connector.cursor:Request id: c4538fad-b305-431d-ad4a-a8cb7a99e530
# DEBUG:snowflake.connector.cursor:running query [SHOW /* sqlalchemy:_get_schema_foreign_keys */ IMPORTED KEYS IN SCHEMA catapult_...]
# DEBUG:snowflake.connector.cursor:is_file_transfer: True
# DEBUG:snowflake.connector.connection:_cmd_query
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict() called
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022130282202, 0)
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict(): data to send to server {'entries': [{'id': 0, 'timestamp': 43022130282202, 'priority': 0, 'context': {}}]}
# DEBUG:snowflake.connector.connection:sql=[SHOW /* sqlalchemy:_get_schema_foreign_keys */ IMPORTED KEYS IN SCHEMA catapult_...], sequence_id=[11], is_file_transfer=[False]
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: e8a154a3-0ff7-4658-b63c-188cd8046928
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /queries/v1/query-request?requestId=c4538fad-b305-431d-ad4a-a8cb7a99e530&request_guid=e8a154a3-0ff7-4658-b63c-188cd8046928 HTTP/1.1" 200 1431
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.network:Query id: 01b05f7b-0000-2da8-0000-38950011b5ca
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() called: data from server: {'entries': [{'id': 0, 'timestamp': 43022130552572, 'priority': 0}]}
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022130282202, 0)
# DEBUG:snowflake.connector._query_context_cache:deserialize {'id': 0, 'timestamp': 43022130552572, 'priority': 0}
# DEBUG:snowflake.connector._query_context_cache:sync_priority_map called priority_map size = 0, new_priority_map size = 1
# DEBUG:snowflake.connector._query_context_cache:trim_cache() called. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:trim_cache() returns. treeSet size is 1 and cache capacity is 5
# DEBUG:snowflake.connector._query_context_cache:deserialize_json_dict() returns
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022130552572, 0)
# DEBUG:snowflake.connector.cursor:sfqid: 01b05f7b-0000-2da8-0000-38950011b5ca
# INFO:snowflake.connector.cursor:query execution done
# DEBUG:snowflake.connector.cursor:SUCCESS
# DEBUG:snowflake.connector.cursor:PUT OR GET: False
# DEBUG:snowflake.connector.cursor:Query result format: json
# DEBUG:snowflake.connector.result_batch:parsing for result batch id: 0
# INFO:snowflake.connector.cursor:Number of results in first chunk: 0
# DEBUG:snowflake.connector.result_set:beginning to schedule result batch downloads
# DEBUG:snowflake.connector.connection:cursor
# DEBUG:snowflake.connector.cursor:executing SQL/command
# DEBUG:snowflake.connector.connection:parameters: {}
# DEBUG:snowflake.connector.cursor:binding: [SHOW /* sqlalchemy:_get_schema_unique_constraints */ UNIQUE KEYS IN SCHEMA catap...] with input=[{}], processed=[{}]
# INFO:snowflake.connector.cursor:query: [SHOW /* sqlalchemy:_get_schema_unique_constraints */ UNIQUE KEYS IN SCHEMA catap...]
# DEBUG:snowflake.connector.connection:sequence counter: 12
# DEBUG:snowflake.connector.cursor:Request id: 571224b4-8b90-4804-93ac-fee2652ece5c
# DEBUG:snowflake.connector.cursor:running query [SHOW /* sqlalchemy:_get_schema_unique_constraints */ UNIQUE KEYS IN SCHEMA catap...]
# DEBUG:snowflake.connector.cursor:is_file_transfer: True
# DEBUG:snowflake.connector.connection:_cmd_query
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict() called
# DEBUG:snowflake.connector._query_context_cache:Cache Entry: (0, 43022130552572, 0)
# DEBUG:snowflake.connector._query_context_cache:serialize_to_dict(): data to send to server {'entries': [{'id': 0, 'timestamp': 43022130552572, 'priority': 0, 'context': {}}]}
# DEBUG:snowflake.connector.connection:sql=[SHOW /* sqlalchemy:_get_schema_unique_constraints */ UNIQUE KEYS IN SCHEMA catap...], sequence_id=[12], is_file_transfer=[False]
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# ...
# 	pmh_heartattacknotes VARCHAR(16777216),
# 	pmh_cholecystectomynotes VARCHAR(16777216),
# 	pmh_carotidendarterectomynotes VARCHAR(16777216),
# 	pmh_comments VARCHAR(16777216),
# 	fa_notes VARCHAR(16777216),
# 	pmh_atrialfibrillationnotes VARCHAR(16777216),
# 	pmh_hysterectomynotes VARCHAR(16777216),
# 	pmh_headinjurynotes VARCHAR(16777216),
# 	pmh_pressureulcernotes VARCHAR(16777216),
# 	pmh_pneumonianotes VARCHAR(16777216),
# 	ros_comments VARCHAR(16777216),
# 	pmh_appendectomynotes VARCHAR(16777216),
# 	height VARCHAR(16777216),
# 	pmh_herniarepairnotes VARCHAR(16777216),
# 	pmh_osteoarthritisnotes VARCHAR(16777216),
# 	pmh_obesitynotes VARCHAR(16777216),
# 	pmh_heartdiseasenotes VARCHAR(16777216),
# 	pmh_hypertensionnotes VARCHAR(16777216),
# 	ps_cancerscreeningnotes VARCHAR(16777216),
# 	pmh_prostatectomynotes VARCHAR(16777216),
# 	ps_cancerscreeningcologuardnotes VARCHAR(16777216),
# 	ps_mammogramnotes VARCHAR(16777216),
# 	bp_sys VARCHAR(16777216),
# 	bp_dia VARCHAR(16777216),
# 	hr VARCHAR(16777216),
# 	depression_comments VARCHAR(16777216),
# 	pmh_anemianotes VARCHAR(16777216),
# 	pmh_copdnotes VARCHAR(16777216),
# 	ps_cancerscreeningfecalnotes VARCHAR(16777216),
# 	printed_tips VARCHAR(16777216),
# 	pmh_cataractsurgerynotes VARCHAR(16777216),
# 	pmh_coronaryarterybypassgraftnotes VARCHAR(16777216),
# 	pmh_mastectomynotes VARCHAR(16777216),
# 	pmh_kidneydiseasenotes VARCHAR(16777216),
# 	pmh_strokenotes VARCHAR(16777216),
# 	hpi_comments VARCHAR(16777216),
# 	pmh_peripheralvasculardiseasenotes VARCHAR(16777216),
# 	familyhistory_diabetesnotes VARCHAR(16777216),
# 	pmh_breastbiopsynotes VARCHAR(16777216),
# 	pmh_burnsnotes VARCHAR(16777216),
# 	ps_cancerscreeningcolonoscopynotes VARCHAR(16777216),
# 	pmh_atrialflutternotes VARCHAR(16777216),
# 	waist VARCHAR(16777216),
# 	freenote VARCHAR(16777216),
# 	pmh_gerdnotes VARCHAR(16777216),
# 	pmh_rheumatoidarthritisnotes VARCHAR(16777216),
# 	pmh_constipationnotes VARCHAR(16777216),
# 	pmh_schizophrenianotes VARCHAR(16777216),
# 	weight VARCHAR(16777216),
# 	pmh_implantabledefibrillatornotes VARCHAR(16777216),
# 	pmh_pacemakernotes VARCHAR(16777216),
# 	pmh_deepveinthrombosisnotes VARCHAR(16777216),
# 	riskfactor_notes VARCHAR(16777216),
# 	maannotations VARCHAR(16777216),
# 	pmh_coronarystentnotes VARCHAR(16777216),
# 	pmh_drugoralcoholdependencenotes VARCHAR(16777216),
# 	pmh_sicklecellnotes VARCHAR(16777216),
# 	pmh_organtransplantnotes VARCHAR(16777216),
# 	pmh_epilepsynotes VARCHAR(16777216),
# 	pmh_liverdiseasenotes VARCHAR(16777216),
# 	pmh_highcholesterolnotes VARCHAR(16777216),
# 	ps_bonedensitytestnotes VARCHAR(16777216),
# 	pmh_asthmanotes VARCHAR(16777216),
# 	haspcp BOOLEAN,
# 	actionplan VARCHAR(16777216),
# 	bloodpressures VARCHAR(16777216),
# 	clinicid VARCHAR(16777216),
# 	cliniclocation VARCHAR(16777216),
# 	commentslist VARCHAR(16777216),
# 	effectivedate VARCHAR(16777216),
# 	healtheventid VARCHAR(16777216),
# 	heartrates VARCHAR(16777216),
# 	notes VARCHAR(16777216),
# 	numberofkitsreceived VARCHAR(16777216),
# 	questionnairestarted BOOLEAN,
# 	registrationdate TIMESTAMP_NTZ,
# 	relationtoinsured VARCHAR(16777216)
# )
#
# /*
# 3 rows from healthrecorddata table:
# virtual_clinic_test_selection__c	registrationtokitshipmentindays	registrationtosamplecollectionindays	kitdeliverytosampleshippedindays	kitdeliverytoconsultcompletedindays	kitdeliverytoquestionnairestartedindays	sku	labordercreateddate	companyname	age	biologicalsex	mailingcity	mailingzipcode	preferredlanguage	registrationcreateddate	insuranceeffectivedate	insurancerelationtoinsured	kitsordered	techconnectend	consultcompleted	clinicstartdate	companyaccountmanager	companyindustry	invitationsent	registrationstatus	location_name__c	healtheventstartdate	hdl	ldl	chol	a1c	tgs	pmh_insomnianotes	pmh_diabetesnotes	pmh_heartattacknotes	pmh_cholecystectomynotes	pmh_carotidendarterectomynotes	pmh_comments	fa_notes	pmh_atrialfibrillationnotes	pmh_hysterectomynotes	pmh_headinjurynotes	pmh_pressureulcernotes	pmh_pneumonianotes	ros_comments	pmh_appendectomynotes	height	pmh_herniarepairnotes	pmh_osteoarthritisnotes	pmh_obesitynotes	pmh_heartdiseasenotes	pmh_hypertensionnotes	ps_cancerscreeningnotes	pmh_prostatectomynotes	ps_cancerscreeningcologuardnotes	ps_mammogramnotes	bp_sys	bp_dia	hr	depression_comments	pmh_anemianotes	pmh_copdnotes	ps_cancerscreeningfecalnotes	printed_tips	pmh_cataractsurgerynotes	pmh_coronaryarterybypassgraftnotes	pmh_mastectomynotes	pmh_kidneydiseasenotes	pmh_strokenotes	hpi_comments	pmh_peripheralvasculardiseasenotes	familyhistory_diabetesnotes	pmh_breastbiopsynotes	pmh_burnsnotes	ps_cancerscreeningcolonoscopynotes	pmh_atrialflutternotes	waist	freenote	pmh_gerdnotes	pmh_rheumatoidarthritisnotes	pmh_constipationnotes	pmh_schizophrenianotes	weight	pmh_implantabledefibrillatornotes	pmh_pacemakernotes	pmh_deepveinthrombosisnotes	riskfactor_notes	maannotations	pmh_coronarystentnotes	pmh_drugoralcoholdependencenotes	pmh_sicklecellnotes	pmh_organtransplantnotes	pmh_epilepsynotes	pmh_liverdiseasenotes	pmh_highcholesterolnotes	ps_bonedensitytestnotes	pmh_asthmanotes	haspcp	actionplan	bloodpressures	clinicid	cliniclocation	commentslist	effectivedate	healtheventid	heartrates	notes	numberofkitsreceived	questionnairestarted	registrationdate	relationtoinsured
# Individual Tasso (Catapult Labs)	42	45	2	713	2	Unknown	2021-04-06 05:00:05	Company One	28	M	Irving	75063	en	2021-02-23 16:22:58	None	EMPLOYEE	7	2023-03-28 10:18:43	True	2023-03-08 00:00:00	Agent Rambo	Healthcare	True	CONSULT_COMPLETED	Dallas	2023-03-08 00:00:00	43	87	158	4.9	139	None	None	None	None	None	None	None	None	None	None	None	None	Denies cp or SOB	None	68	None	None	None	None	None	None	None	None	None	120	78	60	Discussed EAP options with pt and to  f/u	None	None	None	* Establish a relationship with an in-network Primary Care Provider for when medical care is needed.	None	None	None	None	None	None	None	None	None	None	None	None	32	Test Free Note	None	None	None	None	169	None	None	None	None	None	None	None	None	None	None	None	None	None	None	False	Pituitary fossa explorat	147	7c09ac9a-ea7c-4ca4-b85c-f6da72fab0f9	Torez	Endometriosis of other specified sites	2023-01-31 11:17:58	94-156-8392	52	Occup of pk-up/van injured in clsn w statnry object nontraf	45	True	2022-12-29 09:25:01	Asteraceae
# Individual Tasso (Catapult Labs)	2	9	4	None	2	Unknown	2021-02-24 05:00:05	Company One	28	M	Irving	75063	en	2021-02-23 16:22:58	None	EMPLOYEE	3	2023-03-28 10:18:43	True	2023-03-08 00:00:00	Agent Rambo	Healthcare	True	CONSULT_COMPLETED	Dallas	2023-03-08 00:00:00	43	87	158	4.9	139	None	None	None	None	None	None	None	None	None	None	None	None	Denies cp or SOB	None	68	None	None	None	None	None	None	None	None	None	120	78	60	Discussed EAP options with pt and to  f/u	None	None	None	* Establish a relationship with an in-network Primary Care Provider for when medical care is needed.	None	None	None	None	None	None	None	None	None	None	None	None	32	Test Free Note	None	None	None	None	169	None	None	None	None	None	None	None	None	None	None	None	None	None	None	False	Large bowel incision	190	d746a26f-bc71-4db1-b730-89c5b145eecc	Xinglong	Other specified anomalies of upper alimentary tract	2023-08-20 3:17:24	16-450-7521	50	Ulnar collateral ligament sprain of right elbow, subs encntr	52	True	2023-02-06 02:42:55	Cladoniaceae
# Individual Tasso (Catapult Labs)	3	None	2	None	2	Unknown	2022-02-28 06:00:03	Company One	28	M	Irving	75063	en	2022-02-27 16:46:47	None	EMPLOYEE	3	2023-03-28 10:18:43	True	2023-03-08 00:00:00	Agent Rambo	Healthcare	False	HOME_KIT_RECEIVED_BY_PATIENT	Dallas	2023-03-08 00:00:00	43	87	158	4.9	139	None	None	None	None	None	None	None	None	None	None	None	None	Denies cp or SOB	None	68	None	None	None	None	None	None	None	None	None	120	78	60	Discussed EAP options with pt and to  f/u	None	None	None	* Establish a relationship with an in-network Primary Care Provider for when medical care is needed.	None	None	None	None	None	None	None	None	None	None	None	None	32	Test Free Note	None	None	None	None	169	None	None	None	None	None	None	None	None	None	None	None	None	None	None	False	Control prostate hemorr	155	bf73caf5-6784-459c-91db-5cbcfd027301	Novopokrovka	Other specified anomalies of upper alimentary tract	2023-03-23 11:11:58	62-423-0909	97	Other hypothyroidism	18	True	2023-07-12 00:49:38	Asteraceae
# */
#
#
# CREATE TABLE healthrecorddata_attributes (
# 	variable_name VARCHAR(16777216),
# 	definition VARCHAR(16777216)
# )
#
# /*
# 3 rows from healthrecorddata_attributes table:
# variable_name	definition
# Virtual_Clinic_Test_Selection__c	Selection made for tests in a virtual clinic environment.
# RegistrationToKitShipmentInDays	The number of days between registration and the shipment of the test kit.
# RegistrationToSampleCollectionInDays	The number of days between registration and the collection of a sample.
# */
# INFO:snowflake.connector.connection:Snowflake Connector for Python Version: 3.5.0, Python Version: 3.10.0, Platform: macOS-13.4-arm64-arm-64bit
# DEBUG:snowflake.connector.connection:connect
# DEBUG:snowflake.connector.connection:__config
# INFO:snowflake.connector.connection:This connection is in OCSP Fail Open Mode. TLS Certificates would be checked for validity and revocation status. Any other Certificate Revocation related exceptions or OCSP Responder failures would be disregarded in favor of connectivity.
# DEBUG:snowflake.connector.converter:use_numpy: False
# DEBUG:snowflake.connector.connection:REST API object was created: sn37336.sa-east-1.aws.snowflakecomputing.com:443
# DEBUG:snowflake.connector.auth._auth:authenticate
# DEBUG:snowflake.connector.auth._auth:assertion content: *********
# DEBUG:snowflake.connector.auth._auth:account=sn37336, user=QUBIKA_ELHAIEK, database=CATAPULT_HEALTH_DB, schema=POC_CATAPULT_HEALTH, warehouse=ML_ENGINEER_WH, role=_ML_ENGINEER_CATAPULT_HEALTH_DB, request_id=12e0a8ec-0bff-4c20-8370-b66b0c72a4d8
# DEBUG:snowflake.connector.auth._auth:body['data']: {'CLIENT_APP_ID': 'PythonSnowpark', 'CLIENT_APP_VERSION': '1.10.0', 'SVN_REVISION': None, 'ACCOUNT_NAME': 'sn37336', 'LOGIN_NAME': 'QUBIKA_ELHAIEK', 'CLIENT_ENVIRONMENT': {'APPLICATION': 'streamlit', 'OS': 'Darwin', 'OS_VERSION': 'macOS-13.4-arm64-arm-64bit', 'PYTHON_VERSION': '3.10.0', 'PYTHON_RUNTIME': 'CPython', 'PYTHON_COMPILER': 'Clang 12.0.0 ', 'OCSP_MODE': 'FAIL_OPEN', 'TRACING': 10, 'LOGIN_TIMEOUT': None, 'NETWORK_TIMEOUT': None, 'SOCKET_TIMEOUT': None}, 'SESSION_PARAMETERS': {'CLIENT_PREFETCH_THREADS': 4}}
# DEBUG:snowflake.connector.vendored.urllib3.util.retry:Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# DEBUG:snowflake.connector.vendored.urllib3.util.retry:Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# DEBUG:snowflake.connector.network:remaining request timeout: N/A ms, retry cnt: 1
# DEBUG:snowflake.connector.network:Request guid: 6641b5a4-e8c9-4ed9-8b5b-00819d7981fc
# DEBUG:snowflake.connector.network:socket timeout: 60
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:Starting new HTTPS connection (1): sn37336.sa-east-1.aws.snowflakecomputing.com:443
# DEBUG:snowflake.connector.ssl_wrap_socket:OCSP Mode: FAIL_OPEN, OCSP response cache file name: None
# DEBUG:snowflake.connector.ocsp_snowflake:ocsp_response_cache_uri: file:///Users/miguelelhaiek/Library/Caches/Snowflake/ocsp_response_cache.json
# DEBUG:snowflake.connector.ocsp_snowflake:OCSP_VALIDATION_CACHE size: 200
# DEBUG:snowflake.connector.ocsp_snowflake:OCSP response cache server is enabled: http://ocsp.snowflakecomputing.com/ocsp_response_cache.json
# DEBUG:snowflake.connector.ocsp_snowflake:OCSP dynamic cache server RETRY URL: None
# DEBUG:snowflake.connector.ocsp_snowflake:validating certificate: sn37336.sa-east-1.aws.snowflakecomputing.com
# DEBUG:snowflake.connector.ocsp_asn1crypto:# of certificates: 4
# DEBUG:snowflake.connector.ocsp_asn1crypto:subject: OrderedDict([('common_name', '*.sa-east-1.snowflakecomputing.com')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')]), issuer: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:not found issuer_der: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# DEBUG:snowflake.connector.ocsp_snowflake:hit cache for subject: OrderedDict([('common_name', '*.sa-east-1.snowflakecomputing.com')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:Verifying the attached certificate is signed by the issuer. Valid Not After: 2025-08-23 22:57:03+00:00
# DEBUG:snowflake.connector.ocsp_snowflake:hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:Verifying the attached certificate is signed by the issuer. Valid Not After: 2025-08-23 22:59:53+00:00
# DEBUG:snowflake.connector.ocsp_snowflake:hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# DEBUG:snowflake.connector.ocsp_asn1crypto:Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-06-06 12:00:00+00:00
# DEBUG:snowflake.connector.ocsp_snowflake:hit cache for subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# DEBUG:snowflake.connector.ocsp_snowflake:ok
# DEBUG:snowflake.connector.vendored.urllib3.connectionpool:https://sn37336.sa-east-1.aws.snowflakecomputing.com:443 "POST /session/v1/login-request?request_id=12e0a8ec-0bff-4c20-8370-b66b0c72a4d8&databaseName=CATAPULT_HEALTH_DB&schemaName=POC_CATAPULT_HEALTH&warehouse=ML_ENGINEER_WH&roleName=_ML_ENGINEER_CATAPULT_HEALTH_DB&request_guid=6641b5a4-e8c9-4ed9-8b5b-00819d7981fc HTTP/1.1" 200 1619
# DEBUG:snowflake.connector.network:SUCCESS
# DEBUG:snowflake.connector.network:Session status for SessionPool 'sn37336.sa-east-1.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# DEBUG:snowflake.connector.network:ret[code] = None, after post request
# DEBUG:snowflake.connector.auth._auth:completed authentication
# DEBUG:snowflake.connector.auth._auth:token = ******
# DEBUG:snowflake.connector.auth._auth:master_token = ******
# DEBUG:snowflake.connector.auth._auth:id_token = NULL
# DEBUG:snowflake.connector.auth._auth:mfa_token = NULL
# DEBUG:snowflake.connector.connection:cursor
# INFO:snowflake.snowpark.session:Snowpark Session information:
# "version" : 1.10.0,
# "python.version" : 3.10.0,
# "python.connector.version" : 3.5.0,
# "python.connector.session.id" : 62212604642506,
# "os.name" : Darwin
# 2023-11-16 15:35:44.391 No runtime found, using MemoryCacheStorageManager

# %%
python_repl = PythonREPLTool()
tools = load_tools(['Python_REPL'])

tools.append(sql_query_tool)

# Specify the tools the agent may use
tool_names = [tool.name for tool in tools]



# Initialize st.session_state if it's not already initialized
if not hasattr(st, "session_state"):
    st.session_state = {}

if "messages" not in st.session_state:
    st.session_state.messages = [{"role": "system", "content": get_system_prompt()}]



SUFFIX = """
"Begin! They are going to ask you for data and also ask you to create charts from that data.\n"
"Try to divide the input question into two parts: the part that refers to querying the database and the part of the input question where you are asked to graph the results of the question to the database."
"You will be acting as an AI Snowflake SQL Expert named Catapult Health Bot."
"Your goal is to give correct, executable sql query to users."
"You will be replying to users who will be confused if you don't respond in the character of Catapult Health Bot."
"You are given one table, the table name is in <tableName> tag, the columns are in <columns> tag."
"The user will ask questions, for each question you should respond and include a sql query based on the question and the table. "

"{context}"

" You MUST MUST wrap the generated python code within ``` python code markdown in this format e.g"
"```python"
"import pandas as pd"
"df = pd.DataFrame([(2878, datetime.date(2023, 2, 22)), (2909, datetime.date(2023, 2, 23)), (2977, datetime.date(2023, 2, 24)), (4184, datetime.date(2023, 2, 21)), (25123, datetime.date(2023, 2, 20)), (31730, datetime.date(2023, 2, 19)), (24394, datetime.date(2023, 2, 18))], columns=['cantidad_lineas_diferentes', 'fecha'])"
"st.bar_chart(df, x='fecha', y='cantidad_lineas_diferentes')
"```
"Use the 'Python_REPL' tool to make the charts, whenever the input begins in one of the following possible ways: " 
"show a bar chart..., show a pie chart..., show a line chart... plot a bar chart..., plot a pie chart..., plot a line chart... Most of the time, in the responses, you will have to show charts. "
"Don't explain the query before retrieving it,just show the SQL Query, the dataframe result and if it's the case, the chart required for the user. You MUST NOT be verbose on the explanation, just show the results."


"Use the 'Python_REPL' tool to make the charts, whenever the input begins in one of the following possible ways: "
"show a bar chart..., show a pie chart..., show a line chart... plot a bar chart..., plot a pie chart..., plot a line chart... Most of the time, in the responses, you will have to show charts. "
"To make these charts, you first need to create a pandas dataframe with the result of the database query. Intelligently select the columns of this dataframe that will be used to display the chart. For example:"
"import streamlit as st"
"import pandas as pd"
"import datetime"
"import plotly.express as px"
"df = pd.DataFrame([(2878, datetime.date(2023, 2, 22)), (2909, datetime.date(2023, 2, 23)), (2977, datetime.date(2023, 2, 24)), (4184, datetime.date(2023, 2, 21)), (25123, datetime.date(2023, 2, 20)), (31730, datetime.date(2023, 2, 19)), (24394, datetime.date(2023, 2, 18))], columns=['cantidad_lineas_diferentes', 'fecha'])"
"st.bar_chart(df, x='fecha', y='cantidad_lineas_diferentes')"
"These charts should be made using as input the results of the query to the table <tableName>. "
"To make these charts, use the Plotly library, importing only the necessary libraries. "
"Do not import libraries that will not be used. Import one library at a time. "
"There should be only one import per line. "
"Use the 'Python_REPL' tool for the final response, after obtaining the response to the database query. "
"The final response of the 'Python_REPL' tool should not be in triple quotes, the python code should be executed. "
"When you do not use the 'Python_REPL' tool, respond to the question in English. Use the 'Python_REPL' tool when the input begins in the following way: "
"Show a line chart..."

"Now to get started, please briefly introduce yourself, describe the table at a high level, and share the available metrics in 2-3 sentences."
"Then provide 3 example questions using bullet points."
"Request: {input}\n"
"{agent_scratchpad}"
"""


from langchain import PromptTemplate

# prompt = ZeroShotAgent.create_prompt(
#     tools, prefix=PREFIX, suffix=get_system_prompt(), input_variables=["input", "agent_scratchpad"]
# )

llm_chain = LLMChain(llm=llm, prompt=prompt)


# Specify the tools the agent may use
tool_names = [tool.name for tool in tools]
agent = ZeroShotAgent(llm_chain=llm_chain, allowed_tools=tool_names)

# Create the AgentExecutor
agent_executor = AgentExecutor.from_agent_and_tools(
    agent=agent, tools=tools, verbose=True
)

# %%
llm_chain = LLMChain(llm=llm, prompt=prompt)
